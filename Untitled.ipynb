# %%
v = "********************"
pl=['I','II','III']
print(v)
def vvd(v,pl): 
    for i in range(len(v)):
        if i%5 == 0:
            print('|',end="   ")
            for j in range(i,i+5):
                print(v[j],' ',end=' '); 
            print('|',end=" ")
            if i < 15:
                print("Игрок",str(pl[i//5]), " :",sep='')
            print()

vvd(v,pl)
k = 1 
print("В случае возникновения вопроса введите '?'")
b = input("Введите номер строки:")
a = input('Введите номер столбца:')
print(a,b)
# Out:
# ********************
# |   *   *   *   *   *   | ИгрокI :
#
# |   *   *   *   *   *   | ИгрокII :
#
# |   *   *   *   *   *   | ИгрокIII :
#
# |   *   *   *   *   *   |
# В случае возникновения вопроса введите '?'
