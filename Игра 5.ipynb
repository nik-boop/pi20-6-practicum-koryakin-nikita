# %%
import re
pl=['@','#','$']
v = [list("|*****|") for i in range(4)]
#print(v)
pm = '''\nПравила игры - игроки поочередно вводят координаты клеток поля заполняя его своими символами.\n
Игроки должны стараться чтобы символы не были расположены рядом в соседних клетках \n
(имели общую сторону или были расположены наискосок друг от друга). За каждое соседство добавляется штрафной бал.\n
Игрок с наименьшим количеством балов побеждает. Справа от игрового поля выводится количество штрафных баллов для каждого игрока\n
а также чей сейчас ход. Теперь введите пожалуйста следующие координаты.'''

def pr():
    global v,pl,k,bl
    for i in range(-2,1):
        if a + i > -1 and a + i < 4:
            for j in range(-1, 2):
                if v[a+i][b+j] == pl[k]:
                    bl[k]+=1
    v[a-1][b]=pl[k]

def vvd(): # Функция вывода интерфейса
    global v,pl,k,bl 
    for i in range(4):
        for j in range(7):
            print(v[i][j],end=' '); 
        if i < 3:
            print("Игрок ",str(pl[i]), " :",str(bl[i]),sep='')
        else:
            print("Ход игрока: ",pl[k])

def inp(): # Функция ввожа координат
    global a # Инициализация а как глобальной переменной
    global b # Инициализация b как глобальной переменной
    print()
    print("В случае возникновения вопроса введите '?'")
    s = input("Введите координаты (строка столбец):")
    if "?" in s:
        print(pm);inp()
    elif re.search(r'[^0-9\s]', s): # Есть ли символы кроме цифр и пробелов
        print()
        print("!! Неверно введены координаты"); inp()
    else:
        s = re.split(r'\D+', s) # Разбиение строки на числа
        if len(s)==2:
            try:
                [a,b]=[int(s[0]),int(s[1])]
            except:
                print("!! Введены неправельные координаты"); inp()
            if a > 4 or a < 1 and b > 5 or b < 1:
                print("!! Выход за границы поля"); inp()
            elif v[a-1][b] != "*":
                print("!! Поле уже занято"); inp()
            else:
                pr()# Выявление штрафных баллов 
        else:
            print()
            print("!! Координаты должны состоять из двух чисел разделённые пробелом"); inp()
k = 0
bl=[0,0,0]
while "*" in v[0] or "*" in v[1] or "*" in v[2] or "*" in v[3]:
    k = k%3
    vvd()
    inp()
    k+=1
a = list()
for i in range(3):
    if bl[i]==min(bl):
        a.append(i)
if len(a)>2:
    print("Ничья")
elif len(a)>1:
    print("Победители:",end=" ")
    for i in a:
        print(pl[i],end=" ")
else:
    print(f"Победитель {pl[a[0]]}")
